# %% [markdown]
# # Task 1: Comparing the Implementation of Phixtral and Mixtral

# %% [markdown]
# ### **Resources:**
# **Phixtral:** https://huggingface.co/mlabonne/phixtral-2x2_8
# **Mixtral:** https://huggingface.co/mistralai/Mixtral-8x7B-v0.1
# **Mixtral Instruction Tuned:** https://huggingface.co/mistralai/Mixtral-8x7B-Instruct-v0.1

# %% [markdown]
# 1. Open the model cards for these models and spend 5-10 minutes read and understand.
# 2. Deploy the models and inference on the Server provided to you as a group.

# %% [markdown]
# # Task 2: Implementing MoE as a Task Expert

# %% [markdown]
# **Code by:** Dr. Shahriar Hossain <br>
# **Video explaining this code:** https://youtu.be/3MX4RJbGIVQ <br>

# %% [markdown]
# **Note:** No GPU required for this implementation.

# %% [markdown]
# Write and run the code on colab and submit your notebooks on LMS

# %% [markdown]
# ## Import Dependencies

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Expert Model

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %%
# Define the expert model

# %% [markdown]
# ## Gating Model
# The Gating class selects the most relevant expert for a given input.

# %% [markdown]
# ![2.1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![2.2.PNG](data:image/png;base64,...)

# %%
# Define the gating model

# %% [markdown]
# ## MoE Model:
#
# The MoE model combines multiple trained experts using a gating mechanism.
# By adjusting weights and aggregating outputs, it generates a unified prediction.

# %% [markdown]
# ![3.1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![3.2.PNG](data:image/png;base64,...)

# %%
# Define the MoE model

# %% [markdown]
# ## Generate Dataset

# %% [markdown]
# ![4.1.PNG](data:image/png;base64,...)

# %%
# Generate the dataset

# %% [markdown]
# ![4.2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![4.3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Train Each Expert

# %% [markdown]
# ![5.1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![5.2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Train MoE

# %% [markdown]
# ![6.PNG](data:image/png;base64,...)

# %%
# Create the MoE model with the trained experts

# %% [markdown]
# ## Evaluate All Models and Compare Accuracies

# %%
# Evaluate all models

# %%
# Print Accuracy for Each Expert

# %%
# Print Accuracy for Mixture of Expert Model
